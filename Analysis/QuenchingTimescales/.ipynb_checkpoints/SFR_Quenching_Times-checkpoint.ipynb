# %% [markdown]
# # Computing Quenching Time from sSFR vs Time

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import pickle
import pynbody

# %matplotlib inline
print(mpl.get_backend())
mpl.rc('font',**{'family':'serif','monospace':['Palatino']})
mpl.rc('text', usetex=True)
mpl.rcParams.update({'font.size': 9})

def read_z0(simname):
    '''Function to read in the data file which contains z=0 information for the various halos'''
    data = []
    with open('/home/akinshol/Data/DataFiles_Archive_20191129/'+ simname + '.data', 'rb') as f:
        while True:
            try:
                data.append(pickle.load(f,encoding='latin1'))
            except EOFError:
                break

    data1 = pd.DataFrame(data)
    return data1
    
def read_timesteps(simname):
    '''Function to read in the timestep bulk-processing datafile (from /home/akinhol/Data/Timescales/DataFiles/{name}.data)'''
    data = []
    with open(f'/home/akinshol/Data/Timescales/DataFiles/{simname}.data','rb') as f:
        while True:
            try: 
                data.append(pickle.load(f))
            except EOFError:
                break
    
    data = pd.DataFrame(data)
    return data
# Out:
# module://ipykernel.pylab.backend_inline

# %%
data = []
with open('/home/akinshol/Data/Timescales/QuenchingTimescales_200b.data', 'rb') as f:
    while True:
        try:
            data.append(pickle.load(f,encoding='latin1'))
        except EOFError:
            break

data = pd.DataFrame(data)

data[(data.sim=='h329')&(data.haloid==11)]
# Out:
#           M_star  apoapsis  eccentricity  haloid  has_gas          mass  \
# 83  2.747402e+07       NaN           NaN      11     True  5.129253e+09
#
#        peak_Pram  peak_Pratio  periapsis  quenched  ... tHI_upper tgasloss  \
# 83  1.571818e+08     0.091677   0.222315     False  ...       0.0      0.0
#
#     tgasloss_lower  tgasloss_upper   tinfall  tinfall_lower  tinfall_upper  \
# 83             0.0             0.0  1.185196       1.185196       0.861961
#
#                tquench       tquench_lower       tquench_upper
# 83  0.3688884118204676  0.9925510189654396  0.0570571082479816
#
# [1 rows x 24 columns]

# %% [markdown]
# First, we have defined functions to read in the $z=0$ and the timestep bulk processing .data files.
# We now can run through a test for simulation `h329`, halo 11.

# %%
sim = 'h148'
i = 36

z0 = read_z0(sim)
print(np.unique(z0.haloid))
timesteps = read_timesteps(sim)

z0 = z0[z0.haloid==i]
print(np.array(np.unique(timesteps.z0haloid),dtype=int))
timesteps = timesteps[timesteps.z0haloid==i]
# Out:
# [   1    2    3    5    6    9   10   11   13   14   21   24   27   28
#    30   32   36   37   41   45   47   48   58   61   65   68   80   81
#    96  105  119  127  128  136  163  212  265  278  283  329  372  377
#   384  386  442  491  620  678  699  711  759  914 1004 1024 1201 1217
#  1451 2905 5039]
# [   2    3    5    6    9   10   11   13   14   21   24   27   28   30
#    32   36   37   41   45   47   48   58   61   65   68   80   81   96
#   105  119  127  128  136  163  212  265  278  283  329  372  377  384
#   386  442  491  620  678  699  759  914 1004]

# %%
z0.keys()
# Out:
# Index(['B-V', 'B_mag', 'G_inflow_0', 'G_inflow_1.5', 'G_inflow_2.5',
#        'G_outflow_0', 'G_outflow_1.5', 'G_outflow_2.5', 'Gin_T', 'Gout_T',
#        'HIgasfrac', 'I_mag', 'M_gas', 'M_star', 'R_mag', 'Rmax', 'Rvir', 'SFR',
#        'U_mag', 'V90_Vdisp', 'V_mag', 'Xc', 'Yc', 'Zc', 'a', 'age', 'c', 'c_a',
#        'fMhires', 'feh', 'g_temp', 'gasfrac', 'h1dist', 'haloid', 'hostDist',
#        'hostHalo', 'hostVirialR', 'id2', 'mHI', 'mass', 'n_gas', 'n_particles',
#        'n_star', 'ovdens', 'sSFR', 'sfh', 'sfhbins', 'tquench', 'zgas',
#        'zstar'],
#       dtype='object')

# %%
sfr, mstar, time = np.array(timesteps.sfr,dtype=float), np.array(timesteps.mstar, dtype=float), np.array(timesteps.time,dtype=float)
sfr = sfr[np.argsort(time)]
mstar = mstar[np.argsort(time)]
time = np.sort(time)

sfh, binEdges = z0.sfh.tolist()[0], z0.sfhbins.tolist()[0]
bincenters = 0.5*(binEdges[1:] + binEdges[:-1])
plt.plot(bincenters,sfh)
plt.title('Old method')
plt.xlabel('Time [Gyr]')
plt.ylabel('SFR')
plt.show()

plt.title('New method')
plt.plot(time,sfr)
plt.xlabel('Time [Gyr]')
plt.ylabel('SFR')
plt.show()

# %%
plt.plot(time,mstar)
plt.semilogy()
plt.xlabel('Time [Gyr]')
plt.ylabel('Stellar Mass')
plt.show()

# %%
import scipy
from scipy import interpolate

s = interpolate.InterpolatedUnivariateSpline(time, mstar)
mstar_interpolated = s(bincenters)


plt.plot(bincenters,sfh/mstar_interpolated)
plt.xlabel('Time [Gyr]')
plt.ylabel('sSFR')
plt.semilogy()
plt.show()

# %%
sSFR = sfr/mstar
lbt = 13.8007 - time
plt.figure(dpi=100)
plt.plot(lbt, sSFR)
plt.xlabel('Lookback Time [Gyr]')
plt.ylabel(r'sSFR [yr$^{-1}$]')
plt.semilogy()
plt.gca().invert_xaxis()
plt.show()
# Out:
# /home/akinshol/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
thresh = 1e-11
if z0.sSFR.tolist()[0] < thresh:
    # then the halo is quenched, so we calculate the quenching time
    for i in range(0, len(bincenters)):
        t = np.flip(lbt)[i]
        s = np.flip(sSFR)[i]
        print(t,s)
        if s >= thresh:
            print(f'Quenched (sSFR = {s}) {t} Gyr ago')
            break
        else:
            continue
else:
    print('Unquenched')
# Out:
# Unquenched

# %%
z0_all = read_z0('h148')
timesteps_all = read_timesteps('h148')
print(list(z0_all.haloid))
for haloid in list(z0_all.haloid):
    haloids_with_stars = np.array(timesteps_all.z0haloid,dtype=int)
    
    if not haloid in haloids_with_stars:
        print(f'Halo {haloid} skipped, no stars')
        continue
        
    z0 = z0_all[z0_all.haloid==haloid]
    timesteps = timesteps_all[timesteps_all.z0haloid==haloid]


    sfr, mstar, time = np.array(timesteps.sfr,dtype=float), np.array(timesteps.mstar,dtype=float), np.array(timesteps.time,dtype=float)
    sfr = sfr[np.argsort(time)]
    mstar = mstar[np.argsort(time)]
    time = np.sort(time)

    #s = interpolate.InterpolatedUnivariateSpline(time, mstar)

    #mstar_interpolated = s(bincenters)
    sSFR = sfr/mstar
    lbt = 13.8007 - time

    if z0.sSFR.tolist()[0] < 1e-11:
        # then the halo is quenched, so we calculate the quenching time
        for i in range(0,len(lbt)):
            t = np.flip(lbt)[i]
            s = np.flip(sSFR)[i]
            if s > 1e-11:
                print(f'Halo {haloid}, Quenched (sSFR = {s}) {t} Gyr ago')
                break
            else:
                continue
    else:
        print(f'Halo {haloid}, Unquenched at z = 0')
# Out:
# [1, 2, 3, 5, 6, 9, 10, 11, 13, 14, 21, 24, 27, 28, 30, 32, 36, 37, 41, 45, 47, 48, 58, 61, 65, 68, 80, 81, 96, 105, 119, 127, 128, 136, 163, 212, 265, 278, 283, 329, 372, 377, 384, 386, 442, 491, 620, 678, 699, 711, 759, 914, 1004, 1024, 1201, 1217, 1451, 2905, 5039]
# Halo 1 skipped, no stars
# Halo 2, Unquenched at z = 0
# Halo 3, Unquenched at z = 0
# Halo 5, Unquenched at z = 0
# Halo 6, Unquenched at z = 0
# Halo 9, Unquenched at z = 0
# Halo 10, Unquenched at z = 0
# Halo 11, Unquenched at z = 0
# Halo 13, Quenched (sSFR = 1.7150284388071186e-11) 4.740686687466409 Gyr ago
# Halo 14, Unquenched at z = 0
# Halo 21, Unquenched at z = 0
# Halo 24, Unquenched at z = 0
# Halo 27, Unquenched at z = 0
# Halo 28, Quenched (sSFR = 8.630331322410878e-11) 1.649749271682177 Gyr ago
# Halo 30, Quenched (sSFR = 1.8593476423046948e-10) 6.464608209117172 Gyr ago
# Halo 32, Unquenched at z = 0
# Halo 36, Quenched (sSFR = 1.8667606880871413e-11) 5.191869273211019 Gyr ago
# ...

# %%
def read_old_data():
    '''Function to read in the resulting data file which contains quenching and infall times'''
    data = []
    with open('/home/akinshol/Data/Timescales/QuenchingTimescales_F19.data', 'rb') as f:
        while True:
            try:
                data.append(pickle.load(f,encoding='latin1'))
            except EOFError:
                break

    data = pd.DataFrame(data)
    return data

old_data = read_old_data()
print(old_data[old_data.sim=='h329'].haloid)
print(old_data[old_data.sim=='h329'].tquench)
# Out:
# 51     11
# 52     33
# 53    133
# 54    137
# Name: haloid, dtype: int64
# 51    0.3688884118204676
# 52     5.275914298799698
# 53     9.996300263992152
# 54     9.004573080963421
# Name: tquench, dtype: object

# %%
# path = '/home/akinshol/Data/Timescales/DataFiles20190731/'
names = ['h148','h242','h229','h329']

q_thresh = 1e-11
i_thresh = 1

age = 13.800797497330507

with open('/home/akinshol/Data/Timescales/QuenchingTimescales_sSFR_S20.data','wb') as f:
    for name in names:
        print(f'Simulation {name}')
        
        z0_all = read_z0(name)
        timesteps_all = read_timesteps(name)

        for haloid in list(z0_all.haloid):
            haloids_with_stars = np.array(timesteps_all.z0haloid,dtype=int)

            if not haloid in haloids_with_stars:
                print(f'\t Halo {haloid} skipped, no stars')
                continue

            z0 = z0_all[z0_all.haloid==haloid]
            timesteps = timesteps_all[np.array(timesteps_all.z0haloid,dtype=int)==haloid]

            sfr, mstar, time = np.array(timesteps.sfr,dtype=float), np.array(timesteps.mstar,dtype=float), np.array(timesteps.time,dtype=float)
            sfr = sfr[np.argsort(time)]
            mstar = mstar[np.argsort(time)]
            time = np.sort(time)

            #s = interpolate.InterpolatedUnivariateSpline(time, mstar)

            #mstar_interpolated = s(bincenters)
            sSFR = sfr/mstar
            lbt = 13.8007 - time
            
            is_quenched = z0.sSFR.tolist()[0] < q_thresh
            
            if is_quenched:
                # then the halo is quenched, so we calculate the quenching time
                for i in range(0,len(lbt)):
                    t = np.flip(lbt)[i]
                    s = np.flip(sSFR)[i]
                    if s > 1e-11:
                        print(f'\t Halo {haloid}, Quenched (sSFR = {s}) {t} Gyr ago', end='  ')
                        tq = t
                        break
                    else:
                        continue
                        
                # lower limit on quenching time
                for i in range(1,len(timesteps)+1):
                    t = lbt[-i]
                    s = sSFR[-i]
                    if s > 2e-11:
                        tq_lower = t
                        break
                    else:
                        continue
                        
                # upper limit on quenching time
                for i in range(1,len(timesteps)+1):
                    t = lbt[-i]
                    s = sSFR[-i]
                    if s > 0:
                        tq_upper = t
                        break
                    else:
                        continue     
            else:
                print(f'\t Halo {haloid}, Unquenched at z = 0', end='  ')
                tq = None
                tq_lower = None
                tq_upper = None
                
                
            dist = np.array(timesteps.h1dist, dtype=float)
            time = age - np.array(timesteps.time, dtype=float)

            # get infall time
            try:
                ti = np.max(time[dist <= i_thresh])
                print(f'\t Halo {haloid}, infall {ti} Gyr ago')
            except ValueError:
                print(f'\t Halo {haloid}, never infell')
                ti = None
                
            try:
                ti_lower = np.max(time[dist <= 1.1])
            except ValueError:
                ti_lower = None
                
            try:
                ti_upper = np.max(time[dist <= 0.9])
            except ValueError:
                ti_upper = None
                
            z0mstar = mstar[-1]
            z0nstar = z0.n_star.tolist()[0]

            pickle.dump({
                'haloid':haloid,
                'quenched':is_quenched,
                'tquench':tq,
                'tquench_lower': tq_lower,
                'tquench_upper': tq_upper,
                'tinfall':ti,
                'tinfall_lower': ti_lower,
                'tinfall_upper': ti_upper,
                'M_star': z0mstar,
                'n_star': z0nstar,
                'sim':name                
            }, f, protocol=2)
# Out:
# Simulation h148
# 	 Halo 1 skipped, no stars
# 	 Halo 2, Unquenched at z = 0  	 Halo 2, infall 1.7239215218961164 Gyr ago
# 	 Halo 3, Unquenched at z = 0  	 Halo 3, infall 4.309803804384165 Gyr ago
# 	 Halo 5, Unquenched at z = 0  	 Halo 5, infall 2.5858822827275567 Gyr ago
# 	 Halo 6, Unquenched at z = 0  	 Halo 6, infall 2.5858822827275567 Gyr ago
# 	 Halo 9, Unquenched at z = 0  	 Halo 9, infall 4.740784184796915 Gyr ago
# 	 Halo 10, Unquenched at z = 0  	 Halo 10, infall 2.4507507134785556e-10 Gyr ago
# 	 Halo 11, Unquenched at z = 0  	 Halo 11, infall 6.033725326034679 Gyr ago
# 	 Halo 13, Quenched (sSFR = 1.7150284388071186e-11) 4.740686687466409 Gyr ago  	 Halo 13, infall 6.033725326034679 Gyr ago
# 	 Halo 14, Unquenched at z = 0  	 Halo 14, infall 1.2929411414833467 Gyr ago
# 	 Halo 21, Unquenched at z = 0  	 Halo 21, infall 1.7239215218961164 Gyr ago
# 	 Halo 24, Unquenched at z = 0  	 Halo 24, never infell
# ...

# %%
def read_old_data():
    '''Function to read in the resulting data file which contains quenching and infall times'''
    data = []
    with open('/home/akinshol/Data/Timescales/QuenchingTimescales_sSFR_F19.data', 'rb') as f:
        while True:
            try:
                data.append(pickle.load(f,encoding='latin1'))
            except EOFError:
                break

    data = pd.DataFrame(data)
    return data

def read_new_data():
    '''Function to read in the resulting data file which contains quenching and infall times'''
    data = []
    with open('/home/akinshol/Data/Timescales/QuenchingTimescales_sSFR_S20.data', 'rb') as f:
        while True:
            try:
                data.append(pickle.load(f,encoding='latin1'))
            except EOFError:
                break

    data = pd.DataFrame(data)
    return data

# %%
reiontime = 13 # in our cosmic UV model reionization occurs at z ~ 6.7 or 13 Gyr ago
fig, ax = plt.subplots(1,1,figsize=(4.6,3.5),dpi=300)

data = read_new_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(np.array(data.quenched,dtype=bool))]
# data = data[~((data.sim=='h148')&(data.haloid==759))]


tinfall = np.array(data.tinfall, dtype=float)
tquench = np.array(data.tquench, dtype=float)

ids = np.array(data.haloid, dtype=int)
sim = np.array(data.sim, dtype=str)
mstar = np.array(data.M_star, dtype=float)


im = ax.scatter(tinfall, tquench,
                 c = mstar,
                 linewidths = 0.3,
                 edgecolors = 'k',
                 cmap = 'inferno', 
                 norm = mpl.colors.LogNorm(),
                 marker = 'o',
                 s = 40,
                 zorder = 11)

# plot diagonal line
ax.plot([0,20],[0,20], '--', linewidth=0.8, color='k', zorder=0) 
# plot reionization line
ax.plot([0,20],[reiontime,reiontime], '-.', linewidth=0.8, color='k', zorder=1)
ax.set_xlabel('Lookback Infall Time ($t_{\mathrm{infall}}$) [Gyr]')
ax.set_ylabel('Lookback Quenching Time ($t_{\mathrm{quench}}$) [Gyr]')
ax.set_xlim(0,14)
ax.set_ylim(0,14)

cbar = plt.colorbar(im, ax = ax) 
cbar.ax.set_ylabel(r'Stellar Mass [$\mathrm{M}_{\odot}$]')


ax.tick_params(direction='in',which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

plt.show()

# %% [markdown]
# # Old Data using z=0 stellar content to get the SFH

# %%
reiontime = 13 # in our cosmic UV model reionization occurs at z ~ 6.7 or 13 Gyr ago
fig, ax = plt.subplots(1,1,figsize=(4.25,3.5),dpi=300)

data = read_old_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(np.array(data.quenched,dtype=bool))&(data.n_star > 100)]
# data = data[~((data.sim=='h148')&(data.haloid==759))]


tinfall = np.array(data.tinfall, dtype=float)
tinfall_lower = np.array(data.tinfall_lower,dtype=float)
tinfall_upper = np.array(data.tinfall_upper,dtype=float)

tquench = np.array(data.tquench, dtype=float)
tquench_lower = np.array(data.tquench_lower,dtype=float)
tquench_upper = np.array(data.tquench_upper,dtype=float)

ids = np.array(data.haloid, dtype=int)
sim = np.array(data.sim, dtype=str)
mstar = np.array(data.M_star, dtype=float)


print('loaded data')


ax.errorbar(tinfall, tquench,
             xerr = np.array([np.abs(tinfall-tinfall_upper), np.abs(tinfall-tinfall_lower)]),
             yerr = np.array([np.abs(tquench-tquench_upper), np.abs(tquench-tquench_lower)]),
             fmt = 'o',
             elinewidth=1,
             ecolor='k',
             capsize=2,
             capthick=1,
             mfc = 'none',
             mec = 'none',
             ms = 0,
             zorder = 10)

im = ax.scatter(tinfall, tquench,
                 c = mstar,
                 linewidths = 0.5,
                 edgecolors = 'k',
                 cmap = 'inferno', 
                 norm = mpl.colors.LogNorm(),
                 marker = 'o',
                 s = 40,
                 zorder = 11)


# plot diagonal line
ax.plot([0,20],[0,20], '--', linewidth=0.8, color='k', zorder=0) 
# plot reionization line
ax.plot([0,20],[reiontime,reiontime], '-.', linewidth=0.8, color='k', zorder=1)
ax.set_xlabel('Lookback Infall Time [Gyr ago]')
ax.set_ylabel('Lookback Quenching Time [Gyr ago]')
ax.set_xlim(0,14)
ax.set_ylim(0,14)
ax.set_xticks([0,2,4,6,8,10,12,14])
ax.set_yticks([0,2,4,6,8,10,12,14])

cbar = plt.colorbar(im, ax = ax) 
cbar.ax.set_ylabel(r'Stellar Mass [$\mathrm{M}_{\odot}$]')


ax.tick_params(direction='in',which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

# plt.savefig(r'/home/akinshol/Data/S20/tq_ti_sSFR.png', dpi=300)

plt.show()
# Out:
# loaded data

# %% [markdown]
# # New Data using sfr over time to get the quenching times

# %%
reiontime = 13 # in our cosmic UV model reionization occurs at z ~ 6.7 or 13 Gyr ago
fig, ax = plt.subplots(1,1,figsize=(4.25,3.5),dpi=300)

data = read_new_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(np.array(data.quenched,dtype=bool))&(data.n_star > 100)]
# data = data[~((data.sim=='h148')&(data.haloid==759))]


tinfall = np.array(data.tinfall, dtype=float)
tinfall_lower = np.array(data.tinfall_lower,dtype=float)
tinfall_upper = np.array(data.tinfall_upper,dtype=float)

tquench = np.array(data.tquench, dtype=float)
tquench_lower = np.array(data.tquench_lower,dtype=float)
tquench_upper = np.array(data.tquench_upper,dtype=float)

ids = np.array(data.haloid, dtype=int)
sim = np.array(data.sim, dtype=str)
mstar = np.array(data.M_star, dtype=float)


print('loaded data')

h148_tq_err = 0.31722272420473
tq_err = 0.22216906137112474

syst_err = []
for s in sim:
    if s=='h148':
        syst_err.append(h148_tq_err)
    else:
        syst_err.append(tq_err)
        
syst_err = np.array(syst_err)

tq_upper_err = np.sqrt(np.abs(tquench-tquench_upper)**2 + syst_err**2)
tq_lower_err = np.sqrt(np.abs(tquench-tquench_lower)**2 + syst_err**2)
ti_upper_err = np.sqrt(np.abs(tinfall-tinfall_upper)**2 + syst_err**2)
ti_lower_err = np.sqrt(np.abs(tinfall-tinfall_lower)**2 + syst_err**2)


ax.errorbar(tinfall, tquench,
             xerr = np.array([ti_upper_err, ti_lower_err]),
             yerr = np.array([tq_upper_err, tq_lower_err]),
             fmt = 'o',
             elinewidth=1,
             ecolor='k',
             capsize=1.5,
             capthick=1,
             mfc = 'none',
             mec = 'none',
             ms = 0,
             zorder = 10)

im = ax.scatter(tinfall, tquench,
                 c = mstar,
                 linewidths = 0.5,
                 edgecolors = 'k',
                 cmap = 'inferno', 
                 norm = mpl.colors.LogNorm(),
                 marker = 'o',
                 s = 40,
                 zorder = 11)


# plot diagonal line
ax.plot([0,20],[0,20], '--', linewidth=0.8, color='k', zorder=0) 
# plot reionization line
ax.plot([0,20],[reiontime,reiontime], '-.', linewidth=0.8, color='k', zorder=1)
ax.set_xlabel('Lookback Infall Time [Gyr ago]')
ax.set_ylabel('Lookback Quenching Time [Gyr ago]')
ax.set_xlim(0,14)
ax.set_ylim(0,14)
ax.set_xticks([0,2,4,6,8,10,12,14])
ax.set_yticks([0,2,4,6,8,10,12,14])

cbar = plt.colorbar(im, ax = ax) 
cbar.ax.set_ylabel(r'Stellar Mass [$\mathrm{M}_{\odot}$]')


ax.tick_params(direction='in',which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')




plt.savefig(r'/home/akinshol/Data/S20/tq_ti_sSFR_overtime.png', dpi=300)

plt.show()
# Out:
# loaded data

# %%
timescale = data.tinfall-data.tquench
data[(timescale < 0)&(tquench<8)]
# Out:
#           M_star  haloid  n_star quenched   sim   tinfall  tinfall_lower  \
# 15  3.707061e+06      36     753     True  h148  3.447843       3.878823
# 22  1.067540e+06      61     217     True  h148  4.740784       5.191967
# 25  3.001293e+07      80    6101     True  h148  7.326666       7.326666
# 84  2.715946e+06      73     552     True  h229  4.417549       4.740784
#
#     tinfall_upper   tquench  tquench_lower  tquench_upper
# 15       3.033698  5.191869       5.602647       5.191869
# 22       4.740784  6.033628       6.033628       6.033628
# 25       7.326666  7.932635       8.619510       7.932635
# 84       4.417549  5.063922       5.063922       5.063922

# %%
d = read_z0('h148')
d = d[d.haloid==61]
sfh = d.sfh.tolist()[0]
sfhbins = d.sfhbins.tolist()[0]
bincenters = 0.5*(sfhbins[1:]+sfhbins[:-1])

d2 = read_timesteps('h148')
d2 = d2[d2.haloid==36]

mstar = np.array(d2.mstar)
time = np.array(d2.time)
sfr = np.array(d2.sfr)


sfr = sfr[np.argsort(time)]
mstar = mstar[np.argsort(time)]
time = np.sort(time)


s = interpolate.InterpolatedUnivariateSpline(time, mstar)
mstar_int = s(bincenters)



plt.plot(bincenters,sfh)
# plt.semilogy()
plt.xlim(0,14)
plt.show()

# %%
d = read_timesteps('h148')
d = d[d.haloid==36]


sSFR = np.array(d.sfr/d.mstar, dtype=float)
time = np.array(d.time)

plt.plot(time,sSFR)
plt.semilogy()
plt.xlim(0,14)
plt.show()

# %%
data = read_new_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(data.n_star > 100)]

tinfall = np.array(data.tinfall, dtype=float)
tinfall_upper_error = np.abs(np.array(data.tinfall_upper, dtype=float) - tinfall)
tinfall_lower_error = np.abs(np.array(data.tinfall_lower, dtype=float) - tinfall)

tquench = np.array(data.tquench, dtype=float)
tquench_upper_error = np.abs(np.array(data.tquench_lower, dtype=float) - tquench) # flipped intentionally
tquench_lower_error = np.abs(np.array(data.tquench_upper, dtype=float) - tquench)

tau_upper_err = np.sqrt(tquench_upper_error**2 + tinfall_upper_error**2)
tau_lower_err = np.sqrt(tquench_lower_error**2 + tinfall_lower_error**2)

timescale = tinfall - tquench

q = np.array(data.quenched,dtype=bool)

data[~q]
# Out:
#           M_star  haloid  n_star quenched   sim       tinfall  tinfall_lower  \
# 0   2.268773e+09       2  435389    False  h148  1.723922e+00       2.154902
# 1   1.505383e+09       3  295443    False  h148  4.309804e+00       4.740784
# 2   4.317847e+08       5   85749    False  h148  2.585882e+00       3.033698
# 3   3.315968e+08       6   65528    False  h148  2.585882e+00       3.033698
# 4   2.359537e+08       9   47542    False  h148  4.740784e+00       4.740784
# 5   2.452897e+07      10    4919    False  h148  2.450751e-10       0.430980
# 6   1.353323e+08      11   26093    False  h148  6.033725e+00       6.033725
# 8   1.241519e+07      14    2459    False  h148  1.292941e+00       1.649847
# 9   4.102691e+06      21     815    False  h148  1.723922e+00       1.723922
# 11  1.004160e+08      27   20102    False  h148  7.326666e+00       7.326666
# 14  3.171186e+06      32     634    False  h148  1.723922e+00       2.154902
# ...

# %% [markdown]
# # Again, old data with z=0 stellar content

# %%
data = read_old_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(data.n_star > 100)]

sim = np.array(data.sim,dtype=str)

h148_tq_err = 0.31722272420473
tq_err = 0.22216906137112474

syst_err = []
for s in sim:
    if s=='h148':
        syst_err.append(h148_tq_err)
    else:
        syst_err.append(tq_err)
        
syst_err = np.array(syst_err)

tinfall = np.array(data.tinfall, dtype=float)
tinfall_upper_error = np.abs(np.array(data.tinfall_upper, dtype=float) - tinfall)
tinfall_lower_error = np.abs(np.array(data.tinfall_lower, dtype=float) - tinfall)

tquench = np.array(data.tquench, dtype=float)
tquench_upper_error = np.abs(np.array(data.tquench_lower, dtype=float) - tquench) # flipped intentionally
tquench_lower_error = np.abs(np.array(data.tquench_upper, dtype=float) - tquench)

tau_upper_err = np.sqrt(tquench_upper_error**2 + tinfall_upper_error**2 + syst_err**2)
tau_lower_err = np.sqrt(tquench_lower_error**2 + tinfall_lower_error**2 + syst_err**2)

fig, ax = plt.subplots(1,1,figsize=(4,2.8),dpi=300)

timescale = tinfall - tquench

q = np.array(data.quenched,dtype=bool)

p1 = ax.errorbar(data.M_star[q],timescale[q],
            yerr = np.array([tau_lower_err[q], tau_upper_err[q]]),
            elinewidth=0.6,
            mec = 'k', 
            mew = 0.3,
            ecolor='#DD3D2D',
            capsize=1.2,
            capthick=0.6,
            fmt='o', 
            color = '#DD3D2D',
            ms = 5,
            zorder=1)#, label='Quenched')



p3 = ax.errorbar(data.M_star[~q], tinfall[~q],
            yerr = [1]*len(tinfall[~q]),
            elinewidth=2,
            mec = 'k', 
            mew = 0.3,
            ecolor='#346eeb',
            capsize=3,
            capthick=2,
            fmt='D',
            color = '#346eeb',
            ms = 5,
            lolims=True,
            zorder=1)#, label='Star-forming')



# zero line
ax.plot([1e2, 1e10], [0,0], 'k--', linewidth=1, alpha=0.3, zorder=0)


# add observational data from Fillingham et al (2015)
x = np.array([2e6, 2e7])
y = np.array([1.4, 1.5])
e1 = ax.scatter(x, y, marker='s', color='k')#, label='Fillingham+15')

# add observational data from Wheeler et al (2014)
x = np.array([1e9])
y = np.array([9.5])
e2 = ax.scatter(x, y, marker = 'h', color='orange', s=55)#, label='Wheeler+14')


# add SMC/LMC data from Kallivayalil
x = np.array([1e9])
y = np.array([1.5])
e3 = ax.errorbar(x, y, xerr = 0.001, yerr=1, 
            elinewidth=2,
            mec = '#8000bf', 
            mew = 0.3,
            ecolor='#8000bf',
            capsize=3,
            capthick=2,
            fmt='p',
            color = '#8000bf',
            ms = 7.5,
            lolims=True,
            zorder=1)#, label='SMC/LMC')

ax.errorbar(x, y,  xerr=5e8, marker = 'p', ms=0,
            ecolor='#8000bf',
            elinewidth=0.6,
            capsize=1.2,
            capthick=0.6,
            fmt='o')

leg1 = ax.legend([e1,e2,e3],['Fillingham et al. (2015)','Wheeler et al. (2014)','SMC/LMC'], loc='lower right', frameon=False, prop={'size':8})
leg2 = ax.legend([p1,p3],['Quenched', 'Star-forming'], loc='upper left', frameon=False, prop={'size':8})
ax.add_artist(leg1)

ax.set_xlim(3e5,6e9)
ax.set_ylim(-11, 11)

ax.set_xlabel('Stellar Mass [$\mathrm{M}_{\odot}$]')
ax.set_ylabel('Quenching Timescale [Gyr]')
# ax.legend(frameon=False, prop={'size':8}, loc='upper left')
ax.semilogx()

ax.tick_params(direction='in',which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

plt.tight_layout()
# plt.savefig(r'/home/akinshol/Data/S20/tq_mass_Present.png', dpi=300)

plt.show()

# %% [markdown]
# # New data with stellar content over time

# %%
data = read_new_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(data.n_star > 100)]

sim = np.array(data.sim,dtype=str)

h148_tq_err = 0.31722272420473
tq_err = 0.22216906137112474

syst_err = []
for s in sim:
    if s=='h148':
        syst_err.append(h148_tq_err)
    else:
        syst_err.append(tq_err)
        
syst_err = np.array(syst_err)

tinfall = np.array(data.tinfall, dtype=float)
tinfall_upper_error = np.abs(np.array(data.tinfall_upper, dtype=float) - tinfall)
tinfall_lower_error = np.abs(np.array(data.tinfall_lower, dtype=float) - tinfall)

tquench = np.array(data.tquench, dtype=float)
tquench_upper_error = np.abs(np.array(data.tquench_lower, dtype=float) - tquench) # flipped intentionally
tquench_lower_error = np.abs(np.array(data.tquench_upper, dtype=float) - tquench)

tau_upper_err = np.sqrt(tquench_upper_error**2 + tinfall_upper_error**2 + 2*syst_err**2)
tau_lower_err = np.sqrt(tquench_lower_error**2 + tinfall_lower_error**2 + 2*syst_err**2)


fig, ax = plt.subplots(1,1,figsize=(4,2.8),dpi=300)

timescale = tinfall - tquench

q = np.array(data.quenched,dtype=bool)

p1 = ax.errorbar(data.M_star[q],timescale[q],
            yerr = np.array([tau_lower_err[q], tau_upper_err[q]]),
            elinewidth=0.6,
            mec = 'k', 
            mew = 0.3,
            ecolor='#DD3D2D',
            capsize=1.2,
            capthick=1.5,
            fmt='o', 
            color = '#DD3D2D',
            ms = 5,
            zorder=1)#, label='Quenched')



p3 = ax.errorbar(data.M_star[~q], tinfall[~q],
            yerr = [1]*len(tinfall[~q]),
            elinewidth=2,
            mec = 'k', 
            mew = 0.3,
            ecolor='#346eeb',
            capsize=3,
            capthick=2,
            fmt='D',
            color = '#346eeb',
            ms = 5,
            lolims=True,
            zorder=1)#, label='Star-forming')



# zero line
ax.plot([1e2, 1e10], [0,0], 'k--', linewidth=1, alpha=0.3, zorder=0)


# add observational data from Fillingham et al (2015)
x = np.array([2e6, 2e7])
y = np.array([1.4, 1.5])
e1 = ax.scatter(x, y, marker='s', color='k')#, label='Fillingham+15')

# add observational data from Wheeler et al (2014)
x = np.array([1e9])
y = np.array([9.5])
e2 = ax.scatter(x, y, marker = 'h', color='orange', s=55)#, label='Wheeler+14')

# add SMC/LMC data from Kallivayalil
x = np.array([1e9])
y = np.array([1.5])
e3 = ax.errorbar(x, y, xerr = 0.001, yerr=1, 
            elinewidth=2,
            mec = '#8000bf', 
            mew = 0.3,
            ecolor='#8000bf',
            capsize=3,
            capthick=2,
            fmt='p',
            color = '#8000bf',
            ms = 7.5,
            lolims=True,
            zorder=1)#, label='SMC/LMC')

ax.errorbar(x, y,  xerr=5e8, marker = 'p', ms=0,
            ecolor='#8000bf',
            elinewidth=0.6,
            capsize=1.2,
            capthick=0.6,
            fmt='o')


# add observational data from Wetzel et al (2015)
x = np.array([3e4, 3e4, 3e6, 3e7, 3e8])
y = np.array([0, 1.5, 0.4, 3.2, 4.7])
y_upperlim = np.array([3, 5.95, 5.6, 6.8, 6.7])
y_lowerlim = np.array([0, 1.05, 0.4, 1.7, 3.1])

y_lower = np.abs(y-y_lowerlim)
y_upper = np.abs(y-y_upperlim)



e4 = ax.errorbar(x, y, yerr = np.array([y_lower, y_upper]), 
                elinewidth=0.6, 
                mec='#777777', 
                mew=1, 
                ecolor='#777777', 
                capsize=1.5, 
                capthick=1.5, 
                fmt='s', 
                color='#777777', 
                ms=5,
                zorder=0)



leg1 = ax.legend([e1,e2,e3,e4],['Fillingham et al. (2015)','Wheeler et al. (2014)','SMC/LMC', 'Wetzel et al. (2015)'], loc='lower right', frameon=False, prop={'size':8})
leg2 = ax.legend([p1,p3],['Quenched', 'Star-forming'], loc='upper left', frameon=False, prop={'size':8})
ax.add_artist(leg1)

ax.set_xlim(3e5,6e9)
ax.set_ylim(-11, 11)

ax.set_xlabel('Stellar Mass [$\mathrm{M}_{\odot}$]')
ax.set_ylabel('Quenching Timescale [Gyr]')
# ax.legend(frameon=False, prop={'size':8}, loc='upper left')
ax.semilogx()

ax.tick_params(direction='in',which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

plt.tight_layout()
plt.savefig(r'/home/akinshol/Data/S20/tq_mass_sSFR_overtime.png', dpi=300)

plt.show()

# %%
new_data = read_new_data()
new_data = new_data[(~np.isnan(np.array(new_data.tinfall,dtype=float)))&(np.array(new_data.quenched,dtype=bool))&(new_data.n_star > 100)]

old_data = read_old_data()
old_data = old_data[(~np.isnan(np.array(old_data.tinfall,dtype=float)))&(np.array(old_data.quenched,dtype=bool))&(old_data.n_star > 100)]

len(new_data),len(old_data)
# Out:
# (38, 37)

# %%
merged_data = pd.merge(old_data, new_data,  how='left', left_on=['sim','haloid'], right_on = ['sim','haloid'], suffixes=('_old','_new'))


differences = pd.DataFrame(columns=['sim','haloid','infall_diff','quenching_diff'])
differences.sim = merged_data.sim
differences.haloid = merged_data.haloid
differences.infall_diff = merged_data.tinfall_new - merged_data.tinfall_old
differences.quenching_diff = merged_data.tquench_new - merged_data.tquench_old

differences
# Out:
#      sim  haloid  infall_diff        quenching_diff
# 0   h148      13          0.0                   nan
# 1   h148      28          0.0    -1.031283164117779
# 2   h148      32          NaN                   nan
# 3   h148      36          0.0   -1.0121266818321502
# 4   h148      37          0.0   -0.5608070620717456
# 5   h148      45          0.0   -0.8309516913514621
# 6   h148      61          0.0                   0.0
# 7   h148      68          0.0   -0.5734465903219608
# 8   h148      80          0.0   -0.5224940282208488
# 9   h148      96          0.0  -0.07086536960980538
# 10  h148     128          0.0                   0.0
# 11  h148     163          0.0                   0.0
# 12  h148     265          0.0                   0.0
# 13  h148     278          0.0                   0.0
# 14  h148     283          0.0   -0.2543419573544181
# 15  h148     329          0.0                   0.0
# 16  h148     386          0.0                   0.0
# ...

# %%
np.mean(np.array(differences.quenching_diff,dtype=float)[~np.isnan(np.array(differences.quenching_diff,dtype=float))])
# Out:
# -0.34426998745353987

# %%
merged_data.keys()
# Out:
# Index(['M_star_old', 'R_mag', 'apoapsis', 'eccentricity', 'haloid', 'has_gas',
#        'mass', 'n_star_old', 'peak_Pram', 'peak_Pratio', 'periapsis',
#        'quenched_old', 'sim', 't90', 'tHI', 'tHI_lower', 'tHI_upper',
#        'tgasloss', 'tgasloss_lower', 'tgasloss_upper', 'tinfall_old',
#        'tinfall_lower', 'tinfall_upper', 'tquench_old', 'tquench_lower',
#        'tquench_upper', 'M_star_new', 'n_star_new', 'quenched_new',
#        'tinfall_new', 'tquench_new'],
#       dtype='object')

# %%
reiontime = 13 # in our cosmic UV model reionization occurs at z ~ 6.7 or 13 Gyr ago
fig, ax = plt.subplots(1,3,figsize=(14,3.5),dpi=300)

tinfall = np.array(merged_data.tinfall_new, dtype=float)
tquench = np.array(merged_data.tquench_new, dtype=float)
mstar = np.array(merged_data.M_star_new, dtype=float)


im = ax[0].scatter(tinfall, tquench,
                 c = mstar,
                 linewidths = 0.3,
                 edgecolors = 'k',
                 cmap = 'inferno', 
                 norm = mpl.colors.LogNorm(),
                 marker = 'o',
                 s = 40,
                 zorder = 11)

# plot diagonal line
ax[0].plot([0,20],[0,20], '--', linewidth=0.8, color='k', zorder=0) 
ax[0].plot([0,20],[reiontime,reiontime], '-.', linewidth=0.8, color='k', zorder=1)
ax[0].set_xlabel('Lookback Infall Time ($t_{\mathrm{infall}}$) [Gyr]')
ax[0].set_ylabel('Lookback Quenching Time ($t_{\mathrm{quench}}$) [Gyr]')
ax[0].set_xlim(0,14)
ax[0].set_ylim(0,14)
ax[0].set_title('Calculated via sSFR')

cbar = plt.colorbar(im, ax = ax[0]) 
cbar.ax.set_ylabel(r'Stellar Mass [$\mathrm{M}_{\odot}$]')

ax[0].tick_params(direction='in',which='both')
ax[0].yaxis.set_ticks_position('both')
ax[0].xaxis.set_ticks_position('both')




tinfall = np.array(merged_data.tinfall_old, dtype=float)
tquench = np.array(merged_data.tquench_old, dtype=float)
mstar = np.array(merged_data.M_star_old, dtype=float)


im = ax[1].scatter(tinfall, tquench,
                 c = mstar,
                 linewidths = 0.3,
                 edgecolors = 'k',
                 cmap = 'inferno', 
                 norm = mpl.colors.LogNorm(),
                 marker = 'o',
                 s = 40,
                 zorder = 11)

# plot diagonal line
ax[1].plot([0,20],[0,20], '--', linewidth=0.8, color='k', zorder=0) 
ax[1].plot([0,20],[reiontime,reiontime], '-.', linewidth=0.8, color='k', zorder=1)
ax[1].set_xlabel('Lookback Infall Time ($t_{\mathrm{infall}}$) [Gyr]')
ax[1].set_ylabel('Lookback Quenching Time ($t_{\mathrm{quench}}$) [Gyr]')
ax[1].set_xlim(0,14)
ax[1].set_ylim(0,14)
ax[1].set_title('Calculated via Cumulative SFH')

cbar = plt.colorbar(im, ax = ax[1]) 
cbar.ax.set_ylabel(r'Stellar Mass [$\mathrm{M}_{\odot}$]')


ax[1].tick_params(direction='in',which='both')
ax[1].yaxis.set_ticks_position('both')
ax[1].xaxis.set_ticks_position('both')

diff = merged_data.tquench_new - merged_data.tquench_old
tinfall = merged_data.tinfall_new
mstar = np.array(merged_data.M_star_old, dtype=float)


im = ax[2].scatter(tinfall, diff,
                 c = mstar,
                 linewidths = 0.3,
                 edgecolors = 'k',
                 cmap = 'inferno', 
                 norm = mpl.colors.LogNorm(),
                 marker = 'o',
                 s = 40,
                 zorder = 11)

# plot diagonal line
ax[2].set_xlabel('Lookback Infall Time ($t_{\mathrm{infall}}$) [Gyr]')
ax[2].set_ylabel('New - Old Quenching Time [Gyr]')
ax[2].set_xlim(0,14)
ax[2].set_ylim(-2,2)
ax[2].set_title('Differences')
ax[2].plot([0,20],[0,0], '--', linewidth=0.8,alpha=0.5, color='k', zorder=1)


cbar = plt.colorbar(im, ax = ax[2]) 
cbar.ax.set_ylabel(r'Stellar Mass [$\mathrm{M}_{\odot}$]')


ax[2].tick_params(direction='in',which='both')
ax[2].yaxis.set_ticks_position('both')
ax[2].xaxis.set_ticks_position('both')


plt.subplots_adjust(wspace=0.3)
# plt.savefig(r'/home/akinshol/Data/Final Notebooks/plots/T_quench_calculation_differences.png',dpi=300)
plt.show()
# Out:
# /home/akinshol/anaconda3/envs/py37/lib/python3.7/site-packages/matplotlib/colors.py:1062: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
 
reiontime = 13 # in our cosmic UV model reionization occurs at z ~ 6.7 or 13 Gyr ago
fig, ax = plt.subplots(1,1,figsize=(4.6,3.5),dpi=300)

data = read_new_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(np.array(data.quenched,dtype=bool))&(data.n_star > 100)]
# data = data[~((data.sim=='h148')&(data.haloid==759))]


tinfall = np.array(data.tinfall, dtype=float)
tinfall_lower = np.array(data.tinfall_lower,dtype=float)
tinfall_upper = np.array(data.tinfall_upper,dtype=float)

tquench = np.array(data.tquench, dtype=float)
tquench_lower = np.array(data.tquench_lower,dtype=float)
tquench_upper = np.array(data.tquench_upper,dtype=float)

ids = np.array(data.haloid, dtype=int)
sim = np.array(data.sim, dtype=str)
mstar = np.array(data.M_star, dtype=float)


print('loaded data')


ax.errorbar(tinfall, tquench,
             xerr = np.array([np.abs(tinfall-tinfall_upper), np.abs(tinfall-tinfall_lower)]),
             yerr = np.array([np.abs(tquench-tquench_upper), np.abs(tquench-tquench_lower)]),
             fmt = 'o',
             elinewidth=1,
             ecolor='k',
             capsize=2,
             capthick=1,
             mfc = 'none',
             mec = 'none',
             ms = 0,
             zorder = 10)

im = ax.scatter(tinfall, tquench,
                 c = mstar,
                 linewidths = 0.3,
                 edgecolors = 'k',
                 cmap = 'inferno', 
                 norm = mpl.colors.LogNorm(),
                 marker = 'o',
                 s = 40,
                 zorder = 11)


# plot diagonal line
ax.plot([0,20],[0,20], '--', linewidth=0.8, color='k', zorder=0) 
# plot reionization line
# ax.plot([0,20],[reiontime,reiontime], '-.', linewidth=0.8, color='k', zorder=1)
ax.set_xlabel('Time Since Infall [billions of years]')
ax.set_ylabel('Time Since Quenching [billions of years]')
ax.set_xlim(0,14)
ax.set_ylim(0,14)

cbar = plt.colorbar(im, ax = ax) 
cbar.ax.set_ylabel(r'Stellar Mass [$\mathrm{M}_{\odot}$]')


ax.tick_params(direction='in',which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

plt.savefig(r'/home/akinshol/Data/Final Notebooks/plots/tq_ti_F19_sSFR_Goldwater.png', dpi=300)

plt.show()
# Out:
# loaded data

# %%
data = read_new_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(data.n_star > 100)]

tinfall = np.array(data.tinfall, dtype=float)
tinfall_upper_error = np.abs(np.array(data.tinfall_upper, dtype=float) - tinfall)
tinfall_lower_error = np.abs(np.array(data.tinfall_lower, dtype=float) - tinfall)

tquench = np.array(data.tquench, dtype=float)
tquench_upper_error = np.abs(np.array(data.tquench_lower, dtype=float) - tquench) # flipped intentionally
tquench_lower_error = np.abs(np.array(data.tquench_upper, dtype=float) - tquench)

tau_upper_err = np.sqrt(tquench_upper_error**2 + tinfall_upper_error**2)
tau_lower_err = np.sqrt(tquench_lower_error**2 + tinfall_lower_error**2)

fig, ax = plt.subplots(1,1,figsize=(4,2.8),dpi=300)

timescale = tinfall - tquench

q = np.array(data.quenched,dtype=bool)

p1 = ax.errorbar(data.M_star[q],timescale[q],
            yerr = np.array([tau_lower_err[q], tau_upper_err[q]]),
            elinewidth=0.6,
            mec = 'k', 
            mew = 0.3,
            ecolor='#DD3D2D',
            capsize=1.2,
            capthick=0.6,
            fmt='o', 
            color = '#DD3D2D',
            ms = 5,
            zorder=1)#, label='Quenched')



p3 = ax.errorbar(data.M_star[~q], tinfall[~q],
            yerr = [1]*len(tinfall[~q]),
            elinewidth=2,
            mec = 'k', 
            mew = 0.3,
            ecolor='#346eeb',
            capsize=3,
            capthick=2,
            fmt='D',
            color = '#346eeb',
            ms = 5,
            lolims=True,
            zorder=1)#, label='Star-forming')



# zero line
ax.plot([1e2, 1e10], [0,0], 'k--', linewidth=1, alpha=0.3, zorder=0)


# add observational data from Fillingham et al (2015)
x = np.array([2e6, 2e7])
y = np.array([1.4, 1.5])
e1 = ax.scatter(x, y, marker='s', color='k')#, label='Fillingham+15')

# add observational data from Wheeler et al (2014)
x = np.array([1e9])
y = np.array([9.5])
e2 = ax.scatter(x, y, marker = 'h', color='orange', s=55)#, label='Wheeler+14')


# add SMC/LMC data from Kallivayalil
x = np.array([1e9])
y = np.array([1.5])
e3 = ax.errorbar(x, y, xerr = 0.001, yerr=1, 
            elinewidth=2,
            mec = '#8000bf', 
            mew = 0.3,
            ecolor='#8000bf',
            capsize=3,
            capthick=2,
            fmt='p',
            color = '#8000bf',
            ms = 7.5,
            lolims=True,
            zorder=1)#, label='SMC/LMC')

ax.errorbar(x, y,  xerr=5e8, marker = 'p', ms=0,
            ecolor='#8000bf',
            elinewidth=0.6,
            capsize=1.2,
            capthick=0.6,
            fmt='o')

leg1 = ax.legend([e1,e2,e3],['Fillingham et al. (2015)','Wheeler et al. (2014)','SMC/LMC'], loc='lower right', frameon=False, prop={'size':8})
leg2 = ax.legend([p1,p3],['Quenched', 'Star-forming'], loc='upper left', frameon=False, prop={'size':8})
ax.add_artist(leg1)

ax.set_xlim(3e5,6e9)
ax.set_ylim(-11, 11)
# ax.set_ylim(-14,3)

ax.set_xlabel('Stellar Mass [$\mathrm{M}_{\odot}$]')
ax.set_ylabel('Quenching Timescale [billions of years]')
# ax.legend(frameon=False, prop={'size':8}, loc='upper left')
ax.semilogx()

ax.tick_params(direction='in',which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

plt.tight_layout()
plt.savefig(r'/home/akinshol/Data/Final Notebooks/plots/tq_mass_F19_sSFR.png', dpi=300)

plt.show()

# %%
# Out:
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
new_data = read_new_data()
new_data = new_data[(~np.isnan(np.array(new_data.tinfall,dtype=float)))&(new_data.n_star > 100)]

old_data = read_old_data()
old_data = old_data[(~np.isnan(np.array(old_data.tinfall,dtype=float)))&(old_data.n_star > 100)]

merged_data = pd.merge(old_data, new_data,  how='left', left_on=['sim','haloid'], right_on = ['sim','haloid'], suffixes=('_old','_new'))
merged_data
# Out:
#       M_star_old      R_mag  apoapsis  eccentricity  haloid  has_gas  \
# 0   2.268773e+09 -19.151902       NaN           NaN       2     True
# 1   1.505383e+09 -18.183868  0.718670      0.126478       3     True
# 2   4.317847e+08 -16.934670       NaN           NaN       5     True
# 3   3.315968e+08 -16.800934       NaN           NaN       6     True
# 4   2.359537e+08 -15.972780  0.854932      0.380107       9     True
# 5   1.353323e+08 -16.444684  0.776306      0.443954      11     True
# 6   1.043767e+08 -15.025933  1.134880      0.452208      13     True
# 7   1.241519e+07 -13.603582       NaN           NaN      14     True
# 8   4.102691e+06 -12.377742       NaN           NaN      21     True
# 9   1.004160e+08 -15.515721  0.925620      0.454809      27     True
# 10  8.417204e+07 -15.117608  0.994081      0.611920      28     True
# 11  3.171186e+06 -11.944739       NaN           NaN      32     True
# 12  3.707061e+06 -11.572734       NaN           NaN      36    False
# ...

# %%
for sim,i,n,o in zip(merged_data.sim,merged_data.haloid,merged_data.quenched_new, merged_data.quenched_old):
    if n!=o:
        print(sim,i)
# Out:
# h148 32

# %%
merged_data[(merged_data.sim=='h148')&(merged_data.haloid==32)].T
# Out:
#                                     11
# M_star_old                 3.17119e+06
# R_mag                         -11.9447
# apoapsis                           NaN
# eccentricity                       NaN
# haloid                              32
# has_gas                           True
# mass                       3.44488e+09
# n_star_old                         634
# peak_Pram                  1.62742e+08
# peak_Pratio                    1.84042
# periapsis                     0.603858
# quenched_old                      True
# sim                               h148
# t90                 2.0834679102475864
# tHI                        2.45075e-10
# tHI_lower                     0.861961
# tHI_upper                  2.45075e-10
# tgasloss                             0
# tgasloss_lower                       0
# tgasloss_upper                       0
# tinfall_old                    1.72392
# tinfall_lower_old               2.1549
# tinfall_upper_old              1.29294
# ...

# %%
old_data[(old_data.sim=='h148')&(old_data.haloid==10)].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [M_star, R_mag, apoapsis, eccentricity, haloid, has_gas, mass, n_star, peak_Pram, peak_Pratio, periapsis, quenched, sim, t90, tHI, tHI_lower, tHI_upper, tgasloss, tgasloss_lower, tgasloss_upper, tinfall, tinfall_lower, tinfall_upper, tquench, tquench_lower, tquench_upper]

# %%
merged_data[(~merged_data.quenched_new)&(merged_data.M_star_new < 1e8)]
# Out:
#       M_star_old      R_mag  apoapsis  eccentricity  haloid  has_gas  \
# 7   1.241519e+07 -13.603582       NaN           NaN      14     True
# 8   4.102691e+06 -12.377742       NaN           NaN      21     True
# 11  3.171186e+06 -11.944739       NaN           NaN      32     True
# 45  2.747402e+07 -14.096046       NaN           NaN      11     True
#
#             mass  n_star_old     peak_Pram  peak_Pratio  ...  \
# 7   9.654919e+09        2459  4.988336e+07     0.397171  ...
# 8   6.522608e+09         815  9.966156e+07     2.535628  ...
# 11  3.444883e+09         634  1.627421e+08     1.840421  ...
# 45  5.129253e+09        5520  1.571818e+08     0.091677  ...
#
#       tquench_upper_old    M_star_new n_star_new quenched_new  tinfall_new  \
# 7   0.07800592820426289  1.241519e+07       2459        False     1.292941
# 8   0.10853226764044166  4.102691e+06        815        False     1.723922
# 11  0.21345346350181238  3.171186e+06        634        False     1.723922
# ...

# %%
merged_data[(~merged_data.quenched_old)&(merged_data.M_star_old < 1e8)]
# Out:
#       M_star_old      R_mag  apoapsis  eccentricity  haloid  has_gas  \
# 7   1.241519e+07 -13.603582       NaN           NaN      14     True
# 8   4.102691e+06 -12.377742       NaN           NaN      21     True
# 45  2.747402e+07 -14.096046       NaN           NaN      11     True
#
#             mass  n_star_old     peak_Pram  peak_Pratio  ...  \
# 7   9.654919e+09        2459  4.988336e+07     0.397171  ...
# 8   6.522608e+09         815  9.966156e+07     2.535628  ...
# 45  5.129253e+09        5520  1.571818e+08     0.091677  ...
#
#       tquench_upper_old    M_star_new n_star_new quenched_new  tinfall_new  \
# 7   0.07800592820426289  1.241519e+07       2459        False     1.292941
# 8   0.10853226764044166  4.102691e+06        815        False     1.723922
# 45   0.0570571082479816  2.747402e+07       5520        False     1.185196
#
#     tinfall_lower_new  tinfall_upper_new  tquench_new  tquench_lower_new  \
# ...

# %%
timesteps_all = read_timesteps('h148')
timesteps = timesteps_all[timesteps_all.z0haloid==10]

# %%
timesteps.h1dist
# Out:
# 5         0.909648
# 57        1.015875
# 109       1.127184
# 161       1.241150
# 213       1.348945
# 265       1.371812
# 317       1.522361
# 368       1.679106
# 419       1.848782
# 470       1.855101
# 521       2.009703
# 572       2.176133
# 623       2.355082
# 674       2.572424
# 724       2.812202
# 774       3.103485
# 824       3.476797
# 873       3.902182
# 922       4.139362
# 971       4.240857
# 1020      4.584302
# 1069      5.126101
# 1118      5.696202
# 1167      6.214104
# 1216      6.720702
# 1265      6.783376
# 1314      7.735037
# 1363      8.029839
# 1412      8.886047
# 1461      9.572023
# 1510     10.308392
# 1559     10.556858
# 1608     11.746649
# 1657     13.605243
# 1706     16.022761
# 1755     24.038068
# 1804     24.767541
# 1853     31.872445
# 1901     70.275422
# 1949     66.811259
# 1996    105.385571
# Name: h1dist, dtype: float64

# %%
def read_file(path, halo_num):
    '''Function to read in the timestep bulk-processing datafile (from /home/akinhol/Data/Timescales/DataFiles/{name}.data)'''
    data = []
    with open(path,'rb') as f:
        while True:
            try: 
                data.append(pickle.load(f))
            except EOFError:
                break
    data = pd.DataFrame(data)
    
    if not halo_num=='all':
        data = data[data.z0haloid == halo_num]

    return data

current_data = read_file('/home/akinshol/Data/Timescales/DataFiles20190731/h148.data', 10)
time = 13.8 - np.array(current_data.time, dtype=float)

np.max(time[np.array(current_data.h1dist) <= 1])
# Out:
# -0.000797497085430976

# %%
merged_data[(merged_data.quenched_new)&(merged_data.M_star_new > 1e8)].T
# Out:
#                                      6
# M_star_old                 1.04377e+08
# R_mag                         -15.0259
# apoapsis                       1.13488
# eccentricity                  0.452208
# haloid                              13
# has_gas                           True
# mass                       9.41582e+09
# n_star_old                       21027
# peak_Pram                  3.53393e+08
# peak_Pratio                    0.27052
# periapsis                     0.428091
# quenched_old                      True
# sim                               h148
# t90                  9.367961844038701
# tHI                            11.6365
# tHI_lower                      12.0675
# tHI_upper                      5.60274
# tgasloss                             0
# tgasloss_lower                       0
# tgasloss_upper                       0
# tinfall_old                    6.03373
# tinfall_lower_old              6.03373
# tinfall_upper_old              5.60274
# ...

# %%
current_data = read_file('/home/akinshol/Data/Timescales/DataFiles20190731/h148.data', 32)
mstar = np.array(current_data.mstar, dtype=float)[0]

sSFR = np.array(current_data['sfr'][time > 13.6])[0] / mstar
print(sSFR)
# Out:
# 0.0

# %%
current_data[current_data.time > 13.6].T
# Out:
#                                                                 14
# HIratio                                         0.7441739655637859
# Pram                                                   2.15566e+07
# Prest                                            593599116.5400963
# Rvir                                                       24.4358
# SNHfrac                                                          0
# a                                                                1
# env_rho                                          560.5639261095546
# fHI                                             0.4266626954973723
# gas_hi           [0.41663743698908, 0.026442665894098, 0.479821...
# gas_mass         [26640.001986313975, 26825.336032567833, 26785...
# gas_r            [0.7076859013564435, 1.7577300936267226, 0.106...
# gas_rho          [4041730.663212081, 74098.30972945174, 6821081...
# gas_temp         [8917.423828125, 12994.998046875, 8583.9521484...
# ...

# %%
data =read_z0('h148')
data[data.haloid==32].T
# Out:
#                                                               15
# B-V                                                     0.572107
# B_mag                                        -10.946749126160444
# G_inflow_0                                                     0
# G_inflow_1.5                                         -0.00634744
# G_inflow_2.5                                        -0.000172989
# G_outflow_0                                                    0
# G_outflow_1.5                                          0.0034963
# G_outflow_2.5                                         0.00506431
# Gin_T                                                    11115.8
# Gout_T                                                   14714.5
# HIgasfrac                                     0.7441739655637859
# I_mag                                        -12.384645265326238
# M_gas                                         13206778.169689339
# ...

# %%
new_data[(new_data.tquench < 9)&(new_data.tinfall-new_data.tquench < 0)]
# Out:
#            M_star  haloid  n_star quenched   sim   tinfall  tinfall_lower  \
# 22   1.067540e+06      61     217     True  h148  4.740784       5.191967
# 25   3.001293e+07      80    6101     True  h148  7.326666       7.326666
# 103  6.107063e+05     447     124     True  h329  2.801372       2.801372
#
#      tinfall_upper   tquench  tquench_lower  tquench_upper
# 22        4.740784  6.101943       6.101943       6.101943
# 25        7.326666  7.808894       7.808894       7.808894
# 103       2.801372  3.538174       3.538174       3.538174

# %%
data =read_z0('h148')
data = data[data.haloid==32]
binedges = data.sfhbins.tolist()[0]
sfh = data.sfh.tolist()[0]
bincenters = 0.5*(binedges[1:] + binedges[:-1])
plt.plot(bincenters, sfh)

# %%
data = read_new_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(data.n_star > 100)]

tinfall = np.array(data.tinfall, dtype=float)
tinfall_upper_error = np.abs(np.array(data.tinfall_upper, dtype=float) - tinfall)
tinfall_lower_error = np.abs(np.array(data.tinfall_lower, dtype=float) - tinfall)

tquench = np.array(data.tquench, dtype=float)
tquench_upper_error = np.abs(np.array(data.tquench_lower, dtype=float) - tquench) # flipped intentionally
tquench_lower_error = np.abs(np.array(data.tquench_upper, dtype=float) - tquench)

tau_upper_err = np.sqrt(tquench_upper_error**2 + tinfall_upper_error**2)
tau_lower_err = np.sqrt(tquench_lower_error**2 + tinfall_lower_error**2)

fig, ax = plt.subplots(1,1,figsize=(4,2.8),dpi=300)

timescale = tinfall - tquench

q = np.array(data.quenched,dtype=bool)

p1 = ax.errorbar(data.M_star[q],timescale[q],
            yerr = np.array([tau_lower_err[q], tau_upper_err[q]]),
            elinewidth=0.6,
            mec = 'k', 
            mew = 0.3,
            ecolor='#DD3D2D',
            capsize=1.2,
            capthick=0.6,
            fmt='o', 
            color = '#DD3D2D',
            ms = 5,
            zorder=1)#, label='Quenched')



p3 = ax.errorbar(data.M_star[~q], tinfall[~q],
            yerr = [1]*len(tinfall[~q]),
            elinewidth=2,
            mec = 'k', 
            mew = 0.3,
            ecolor='#346eeb',
            capsize=3,
            capthick=2,
            fmt='D',
            color = '#346eeb',
            ms = 5,
            lolims=True,
            zorder=1)#, label='Star-forming')



# zero line
ax.plot([1e2, 1e10], [0,0], 'k--', linewidth=1, alpha=0.3, zorder=0)


# add observational data from Fillingham et al (2015)
x = np.array([2e6, 2e7])
y = np.array([1.4, 1.5])
e1 = ax.scatter(x, y, marker='s', color='k')#, label='Fillingham+15')

# add observational data from Wheeler et al (2014)
x = np.array([1e9])
y = np.array([9.5])
e2 = ax.scatter(x, y, marker = 'h', color='orange', s=55)#, label='Wheeler+14')


# add SMC/LMC data from Kallivayalil
x = np.array([1e9])
y = np.array([1.5])
e3 = ax.errorbar(x, y, xerr = 0.001, yerr=1, 
            elinewidth=2,
            mec = '#8000bf', 
            mew = 0.3,
            ecolor='#8000bf',
            capsize=3,
            capthick=2,
            fmt='p',
            color = '#8000bf',
            ms = 7.5,
            lolims=True,
            zorder=1)#, label='SMC/LMC')

ax.errorbar(x, y,  xerr=5e8, marker = 'p', ms=0,
            ecolor='#8000bf',
            elinewidth=0.6,
            capsize=1.2,
            capthick=0.6,
            fmt='o')

leg1 = ax.legend([e1,e2,e3],['Fillingham et al. (2015)','Wheeler et al. (2014)','SMC/LMC'], loc='lower right', frameon=False, prop={'size':8})
leg2 = ax.legend([p1,p3],['Quenched', 'Star-forming'], loc='upper left', frameon=False, prop={'size':8})
ax.add_artist(leg1)

ax.set_xlim(3e5,6e9)
ax.set_ylim(-11, 11)
# ax.set_ylim(-14,3)

ax.set_xlabel('Stellar Mass [$\mathrm{M}_{\odot}$]')
ax.set_ylabel('Quenching Timescale [Gyr]')
# ax.legend(frameon=False, prop={'size':8}, loc='upper left')
ax.semilogx()

ax.tick_params(direction='in',which='both')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

plt.tight_layout()
# plt.savefig(r'/home/akinshol/Data/Final Notebooks/plots/tq_mass_F19_sSFR.png', dpi=300)

plt.show()

# %%
data = read_new_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(data.n_star > 100)]
timescale = np.array(data.tinfall,dtype=float) - np.array(data.tquench,dtype=float)
data = data[(data.M_star >2e6) | (timescale > 0)]
data = data[data.sim=='h148']
list(data.haloid)
# Out:
# /home/akinshol/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in greater
#   after removing the cwd from sys.path.
# [2,
#  3,
#  5,
#  6,
#  9,
#  10,
#  11,
#  13,
#  14,
#  21,
#  27,
#  28,
#  32,
#  36,
#  37,
#  45,
#  68,
#  80,
#  163,
#  278,
#  283,
#  329]

# %%
data = read_new_data()
data = data[(~np.isnan(np.array(data.tinfall,dtype=float)))&(data.n_star > 100)]
# data = data[~((data.sim=='h148')&(data.haloid==759))]

q = np.array(data.quenched,dtype=bool)

tinfall = np.array(data.tinfall, dtype=float)
tinfall_lower = np.array(data.tinfall_lower,dtype=float)
tinfall_upper = np.array(data.tinfall_upper,dtype=float)

tquench = np.array(data.tquench, dtype=float)
tquench_lower = np.array(data.tquench_lower,dtype=float)
tquench_upper = np.array(data.tquench_upper,dtype=float)

ids = np.array(data.haloid, dtype=int)
sim = np.array(data.sim, dtype=str)
mstar = np.array(data.M_star, dtype=float)

# %%
for i in np.array(data[(~q) & (data.M_star < 1e8)].tinfall,dtype=float):
    print(f'{i:.2f} Gyr')
# Out:
# 0.00 Gyr
# 1.29 Gyr
# 1.72 Gyr
# 1.72 Gyr
# 1.19 Gyr

# %%
data = read_timesteps('h329')
data[data.z0haloid==447]
# Out:
#     HIratio          Pram Prest       Rvir  SNHfrac         a env_rho  fHI  \
# 10      0.0  1.155707e+06  None  12.527773      NaN  1.000000    None  0.0
# 21      0.0  5.111106e+05  None  12.457705      NaN  0.985124    None  0.0
# 32      0.0  2.964213e+05  None  12.363016      NaN  0.963028    None  0.0
# 43      0.0  1.154302e+05  None  12.263115      NaN  0.941183    None  0.0
# 54      0.0  9.283978e+04  None  12.293687      NaN  0.919576    None  0.0
# 65      0.0  3.052203e+05  None  11.981369      NaN  0.898197    None  0.0
# 76      0.0  4.790427e+05  None   5.364739      NaN  0.888913    None  0.0
# 87      0.0  7.902901e+05  None   7.298974      NaN  0.877034    None  0.0
# 98      0.0  2.996789e+06  None  14.173291      NaN  0.856075    None  0.0
# 109     0.0  1.097091e+07  None  14.963415      NaN  0.835306    None  0.0
# 120     0.0  1.000542e+08  None  14.017533      NaN  0.814717    None  0.0
#
#     gas_hi gas_mass  ...  sfr          t       time v_env  \
# ...

# %%
names = ['h148','h242','h229','h329']

q_thresh = 1e-11
i_thresh = 1

age = 13.800797497330507

tquenchs, tau_90s = np.array([]), np.array([])
for name in names:
    print(f'Simulation {name}')

    z0_all = read_z0(name)
    timesteps_all = read_timesteps(name)
    
    for haloid in list(np.unique(timesteps_all.z0haloid)):
        haloids_with_stars = np.array(timesteps_all.z0haloid,dtype=int)

        if not haloid in haloids_with_stars:
            print(f'\t Halo {haloid} skipped, no stars')
            continue

        z0 = z0_all[z0_all.haloid==haloid]
        timesteps = timesteps_all[np.array(timesteps_all.z0haloid,dtype=int)==haloid]

        sfr, mstar, time = np.array(timesteps.sfr,dtype=float), np.array(timesteps.mstar,dtype=float), np.array(timesteps.time,dtype=float)
        sfr = sfr[np.argsort(time)]
        mstar = mstar[np.argsort(time)]
        time = np.sort(time)

        #s = interpolate.InterpolatedUnivariateSpline(time, mstar)

        #mstar_interpolated = s(bincenters)
        sSFR = sfr/mstar
        lbt = 13.8007 - time

        is_quenched = z0.sSFR.tolist()[0] < q_thresh

        if is_quenched:
            # then the halo is quenched, so we calculate the quenching time
            for i in range(0,len(lbt)):
                t = np.flip(lbt)[i]
                s = np.flip(sSFR)[i]
                if s > 1e-11:
                    tq = t
                    break
                else:
                    continue
            
            tau_90 = z0.tquench.tolist()[0]
            try: 
                t = float(tau_90)
            except:
                continue 
                
            print(f'\t Halo {haloid}, tquench = {tq:.2f} Gyr ago, tau_90 = {tau_90:.2f} Gyr ago')
            tquenchs = np.append(tquenchs,tq)
            tau_90s = np.append(tau_90s, tau_90)
# Out:
# Simulation h148
# /home/akinshol/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in true_divide
# 	 Halo 13.0, tquench = 4.74 Gyr ago, tau_90 = 9.37 Gyr ago
# 	 Halo 28.0, tquench = 1.65 Gyr ago, tau_90 = 5.04 Gyr ago
# 	 Halo 30.0, tquench = 6.46 Gyr ago, tau_90 = 10.57 Gyr ago
# 	 Halo 36.0, tquench = 5.19 Gyr ago, tau_90 = 8.65 Gyr ago
# 	 Halo 37.0, tquench = 0.43 Gyr ago, tau_90 = 3.90 Gyr ago
# 	 Halo 41.0, tquench = 12.07 Gyr ago, tau_90 = 12.09 Gyr ago
# 	 Halo 45.0, tquench = 4.31 Gyr ago, tau_90 = 6.31 Gyr ago
# 	 Halo 47.0, tquench = 4.31 Gyr ago, tau_90 = 13.19 Gyr ago
# 	 Halo 48.0, tquench = 3.02 Gyr ago, tau_90 = 1.96 Gyr ago
# 	 Halo 58.0, tquench = 12.50 Gyr ago, tau_90 = 12.50 Gyr ago
# 	 Halo 61.0, tquench = 6.03 Gyr ago, tau_90 = 11.54 Gyr ago
# 	 Halo 65.0, tquench = 12.87 Gyr ago, tau_90 = 12.98 Gyr ago
# 	 Halo 68.0, tquench = 1.65 Gyr ago, tau_90 = 4.01 Gyr ago
# ...

# %%
np.mean(tau_90s - tquenchs)
# Out:
# 1.320642350203905

# %%
snapshots = ['h148.cosmo50PLK.3072g3HbwK1BH.004096', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003968', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003840', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003712', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003606', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003584', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003456', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003328', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003200', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003195', 
             'h148.cosmo50PLK.3072g3HbwK1BH.003072', 
             'h148.cosmo50PLK.3072g3HbwK1BH.002944', 
             'h148.cosmo50PLK.3072g3HbwK1BH.002816', 
             'h148.cosmo50PLK.3072g3HbwK1BH.002688', 
             'h148.cosmo50PLK.3072g3HbwK1BH.002554', 
             'h148.cosmo50PLK.3072g3HbwK1BH.002432', 
             'h148.cosmo50PLK.3072g3HbwK1BH.002304', 
             'h148.cosmo50PLK.3072g3HbwK1BH.002176', 
             'h148.cosmo50PLK.3072g3HbwK1BH.002088', 
             'h148.cosmo50PLK.3072g3HbwK1BH.002048', 
             'h148.cosmo50PLK.3072g3HbwK1BH.001920', 
             'h148.cosmo50PLK.3072g3HbwK1BH.001740', 
             'h148.cosmo50PLK.3072g3HbwK1BH.001536', 
             'h148.cosmo50PLK.3072g3HbwK1BH.001408', 
             'h148.cosmo50PLK.3072g3HbwK1BH.001280', 
             'h148.cosmo50PLK.3072g3HbwK1BH.001269', 
             'h148.cosmo50PLK.3072g3HbwK1BH.001152', 
             'h148.cosmo50PLK.3072g3HbwK1BH.001106', 
             'h148.cosmo50PLK.3072g3HbwK1BH.001024', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000974', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000896', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000866', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000768', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000701', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000640', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000512', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000456', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000384', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000347', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000275', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000225', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000188', 
             'h148.cosmo50PLK.3072g3HbwK1BH.000139']

path= '/home/christenc/Data/Sims/h148.cosmo50PLK.3072g/h148.cosmo50PLK.3072g3HbwK1BH/snapshots_200bkgdens/'


times = np.array([])

for snapshot in snapshots:
    s = pynbody.load(path+snapshot)
    print(snapshot)
    times = np.append(times, float(s.properties['time'].in_units('Gyr')))

time_diffs = np.abs(times[1:]-times[:-1])

print(np.mean(time_diffs))
print(np.std(time_diffs))
# Out:
# h148.cosmo50PLK.3072g3HbwK1BH.004096
# h148.cosmo50PLK.3072g3HbwK1BH.003968
# h148.cosmo50PLK.3072g3HbwK1BH.003840
# h148.cosmo50PLK.3072g3HbwK1BH.003712
# h148.cosmo50PLK.3072g3HbwK1BH.003606
# h148.cosmo50PLK.3072g3HbwK1BH.003584
# h148.cosmo50PLK.3072g3HbwK1BH.003456
# h148.cosmo50PLK.3072g3HbwK1BH.003328
# h148.cosmo50PLK.3072g3HbwK1BH.003200
# h148.cosmo50PLK.3072g3HbwK1BH.003195
# h148.cosmo50PLK.3072g3HbwK1BH.003072
# h148.cosmo50PLK.3072g3HbwK1BH.002944
# h148.cosmo50PLK.3072g3HbwK1BH.002816
# h148.cosmo50PLK.3072g3HbwK1BH.002688
# h148.cosmo50PLK.3072g3HbwK1BH.002554
# h148.cosmo50PLK.3072g3HbwK1BH.002432
# h148.cosmo50PLK.3072g3HbwK1BH.002304
# h148.cosmo50PLK.3072g3HbwK1BH.002176
# h148.cosmo50PLK.3072g3HbwK1BH.002088
# h148.cosmo50PLK.3072g3HbwK1BH.002048
# h148.cosmo50PLK.3072g3HbwK1BH.001920
# h148.cosmo50PLK.3072g3HbwK1BH.001740
# h148.cosmo50PLK.3072g3HbwK1BH.001536
# h148.cosmo50PLK.3072g3HbwK1BH.001408
# h148.cosmo50PLK.3072g3HbwK1BH.001280
# ...

# %%
snapnums = ['004096', '004032', '003936', '003840', '003744', '003648', '003606', '003552', '003456', '003360', '003264', '003195', '003168', '003072','002976', '002880', '002784', '002688', '002592', '002554', '002496', '002400', '002304','002208', '002112', '002088', '002016', '001920', '001824','001740','001728','001632', '001536', '001475', '001440', '001344', '001269', '001248','001152', '001106', '001056', '000974', '000960','000864', '000776', '000768', '000672', '000637', '000576', '000480', '000456', '000384', '000347', '000288', '000275', '000225', '000192', '000188', '000139', '000107', '000096', '000071']
name = 'h229'
path= '/home/christenc/Data/Sims/'+name+'.cosmo50PLK.3072g/'+name+'.cosmo50PLK.3072gst5HbwK1BH/snapshots_200bkgdens/'
snapshots = [name+'.cosmo50PLK.3072gst5HbwK1BH.'+snapnum for snapnum in snapnums]

times = np.array([])

for snapshot in snapshots:
    s = pynbody.load(path+snapshot)
    print(snapshot)
    times = np.append(times, float(s.properties['time'].in_units('Gyr')))

time_diffs = np.abs(times[1:]-times[:-1])

print(np.mean(time_diffs))
print(np.std(time_diffs))
# Out:
# h229.cosmo50PLK.3072gst5HbwK1BH.004096
# h229.cosmo50PLK.3072gst5HbwK1BH.004032
# h229.cosmo50PLK.3072gst5HbwK1BH.003936
# h229.cosmo50PLK.3072gst5HbwK1BH.003840
# h229.cosmo50PLK.3072gst5HbwK1BH.003744
# h229.cosmo50PLK.3072gst5HbwK1BH.003648
# h229.cosmo50PLK.3072gst5HbwK1BH.003606
# h229.cosmo50PLK.3072gst5HbwK1BH.003552
# h229.cosmo50PLK.3072gst5HbwK1BH.003456
# h229.cosmo50PLK.3072gst5HbwK1BH.003360
# h229.cosmo50PLK.3072gst5HbwK1BH.003264
# h229.cosmo50PLK.3072gst5HbwK1BH.003195
# h229.cosmo50PLK.3072gst5HbwK1BH.003168
# h229.cosmo50PLK.3072gst5HbwK1BH.003072
# h229.cosmo50PLK.3072gst5HbwK1BH.002976
# h229.cosmo50PLK.3072gst5HbwK1BH.002880
# h229.cosmo50PLK.3072gst5HbwK1BH.002784
# h229.cosmo50PLK.3072gst5HbwK1BH.002688
# h229.cosmo50PLK.3072gst5HbwK1BH.002592
# h229.cosmo50PLK.3072gst5HbwK1BH.002554
# h229.cosmo50PLK.3072gst5HbwK1BH.002496
# h229.cosmo50PLK.3072gst5HbwK1BH.002400
# h229.cosmo50PLK.3072gst5HbwK1BH.002304
# h229.cosmo50PLK.3072gst5HbwK1BH.002208
# ...

# %%
# s = pynbody.load('/home/christenc/Data/Sims/h329.cosmo50PLK.3072g/h329.cosmo50PLK.3072gst5HbwK1BH/snapshots_200bkgdens/h329.cosmo50PLK.3072gst5HbwK1BH.000071')
s = pynbody.load('/home/christenc/Data/Sims/h148.cosmo50PLK.3072g/h148.cosmo50PLK.3072g3HbwK1BH/snapshots_200bkgdens/h148.cosmo50PLK.3072g3HbwK1BH.000139')
s.physical_units()
h = s.halos()
h1 = h[1]

# %%
mass = np.mean(h1.g['mass'].in_units('Msol'))
print(f'Gas: {np.mean(mass):.2e}')
# Out:
# Gas: 2.64e+04

# %%
mass = np.mean(h1.s['mass'].in_units('Msol'))
print(f'Stars: {np.mean(mass):.2e}')
# Out:
# Stars: 1.33e+04

# %%
mass = np.mean(h1.d['mass'].in_units('Msol'))
print(f'Dark Matter: {np.mean(mass):.2e}')
# Out:
# Dark Matter: 4.24e+04

# %% [markdown]
# From Bellovary et al (2019):
#
# These simulations have a force softening resolution of 170 pc, dark matter particle masses are $4.2\times10^4$ solar masses, while gas particles have a mass of $2.7\times10^4$ solar masses and star particles 8000 solar masses.

# %% [markdown]
# From Applebaum et al (2020):
#
# The dark matter particle masses are $1.8\times 10^4$ solar masses, the gas particles begin with  $3.3\times10^3$ solar masses,  and  the  star  particles  form  with  a  mass  of 994 solar masses.
